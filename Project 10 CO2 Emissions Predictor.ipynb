# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
energy=pd.read_csv(r'C:\Users\HP\Downloads\global-data-on-sustainable-energy (1).csv')

# %%
energy.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %%
energy.describe()
# Out:
#               Year  Access to electricity (% of population)  \
# count  3649.000000                              3639.000000
# mean   2010.038367                                78.933702
# std       6.054228                                30.275541
# min    2000.000000                                 1.252269
# 25%    2005.000000                                59.800890
# 50%    2010.000000                                98.361570
# 75%    2015.000000                               100.000000
# max    2020.000000                               100.000000
#
#        Access to clean fuels for cooking  \
# count                        3480.000000
# mean                           63.255287
# std                            39.043658
# min                             0.000000
# 25%                            23.175000
# 50%                            83.150000
# 75%                           100.000000
# max                           100.000000
#
# ...

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Data columns (total 21 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            3649 non-null   object
#  1   Year                                                              3649 non-null   int64
#  2   Access to electricity (% of population)                           3639 non-null   float64
#  3   Access to clean fuels for cooking                                 3480 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita              2718 non-null   float64
#  5   Financial flows to developing countries (US $)                    1560 non-null   float64
#  6   Renewable energy share in the total final energy consumption (%)  3455 non-null   float64
# ...

# %%
energy.columns
# Out:
# Index(['Entity', 'Year', 'Access to electricity (% of population)',
#        'Access to clean fuels for cooking',
#        'Renewable-electricity-generating-capacity-per-capita',
#        'Financial flows to developing countries (US $)',
#        'Renewable energy share in the total final energy consumption (%)',
#        'Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)',
#        'Electricity from renewables (TWh)',
#        'Low-carbon electricity (% electricity)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#        'Value_co2_emissions_kt_by_country',
#        'Renewables (% equivalent primary energy)', 'gdp_growth',
#        'gdp_per_capita', 'Density\n(P/Km2)', 'Land Area(Km2)', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
energy
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
(energy.isnull().mean())*100
# Out:
# Entity                                                               0.000000
# Year                                                                 0.000000
# Access to electricity (% of population)                              0.274048
# Access to clean fuels for cooking                                    4.631406
# Renewable-electricity-generating-capacity-per-capita                25.513839
# Financial flows to developing countries (US $)                      57.248561
# Renewable energy share in the total final energy consumption (%)     5.316525
# Electricity from fossil fuels (TWh)                                  0.575500
# Electricity from nuclear (TWh)                                       3.453001
# Electricity from renewables (TWh)                                    0.575500
# Low-carbon electricity (% electricity)                               1.151000
# Primary energy consumption per capita (kWh/person)                   0.000000
# ...

# %%
col=[var for var in energy.columns if energy[var].isnull().mean()<0.05 and energy[var].isnull().mean()>0 ]

# %%
col
# Out:
# ['Access to electricity (% of population)',
#  'Access to clean fuels for cooking',
#  'Electricity from fossil fuels (TWh)',
#  'Electricity from nuclear (TWh)',
#  'Electricity from renewables (TWh)',
#  'Low-carbon electricity (% electricity)',
#  'Density\\n(P/Km2)',
#  'Land Area(Km2)',
#  'Latitude',
#  'Longitude']

# %%
energy['Access to electricity (% of population)'].median()
# Out:
# 98.36157

# %%
energy['Access to electricity (% of population)']=energy['Access to electricity (% of population)'].fillna(energy['Access to electricity (% of population)'].median())

# %%
energy['Access to clean fuels for cooking']=energy['Access to clean fuels for cooking'].fillna(energy['Access to clean fuels for cooking'].median())

# %%
energy['Renewable energy share in the total final energy consumption (%)']=energy['Renewable energy share in the total final energy consumption (%)'].fillna(energy['Renewable energy share in the total final energy consumption (%)'].median())

# %%
energy['Electricity from fossil fuels (TWh)']=energy['Electricity from fossil fuels (TWh)'].fillna(energy['Electricity from fossil fuels (TWh)'].median())

# %%
energy['Electricity from nuclear (TWh)']=energy['Electricity from nuclear (TWh)'].fillna(energy['Electricity from nuclear (TWh)'].median())

# %%
energy['Electricity from renewables (TWh)']=energy['Electricity from renewables (TWh)'].fillna(energy['Electricity from renewables (TWh)'].median())

# %%
energy['Low-carbon electricity (% electricity)']=energy['Low-carbon electricity (% electricity)'].fillna(energy['Low-carbon electricity (% electricity)'].median())

# %%
energy['Energy intensity level of primary energy (MJ/$2017 PPP GDP)']=energy['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'].fillna(energy['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'].median())

# %%
energy['Density\\n(P/Km2)']=energy['Density\\n(P/Km2)'].fillna(energy['Density\\n(P/Km2)'].mode()[0])

# %%
energy['Land Area(Km2)']=energy['Land Area(Km2)'].fillna(energy['Land Area(Km2)'].median())

# %%
energy['Latitude']=energy['Latitude'].fillna(energy['Latitude'].median())

# %%
energy['Longitude']=energy['Longitude'].fillna(energy['Longitude'].median())

# %%
(energy.isnull().mean())*100
# Out:
# Entity                                                               0.000000
# Year                                                                 0.000000
# Access to electricity (% of population)                              0.000000
# Access to clean fuels for cooking                                    0.000000
# Renewable-electricity-generating-capacity-per-capita                25.513839
# Financial flows to developing countries (US $)                      57.248561
# Renewable energy share in the total final energy consumption (%)     0.000000
# Electricity from fossil fuels (TWh)                                  0.000000
# Electricity from nuclear (TWh)                                       0.000000
# Electricity from renewables (TWh)                                    0.000000
# Low-carbon electricity (% electricity)                               0.000000
# Primary energy consumption per capita (kWh/person)                   0.000000
# ...

# %%
energy['Renewable-electricity-generating-capacity-per-capita']=energy['Renewable-electricity-generating-capacity-per-capita'].fillna(energy['Renewable-electricity-generating-capacity-per-capita'].median())

# %%
energy['Financial flows to developing countries (US $)']=energy['Financial flows to developing countries (US $)'].fillna(energy['Financial flows to developing countries (US $)'].median())

# %%
energy['Value_co2_emissions_kt_by_country']=energy['Value_co2_emissions_kt_by_country'].fillna(energy['Value_co2_emissions_kt_by_country'].median())

# %%
energy['Renewables (% equivalent primary energy)']=energy['Renewables (% equivalent primary energy)'].fillna(energy['Renewables (% equivalent primary energy)'].median())

# %%
energy['gdp_growth']=energy['gdp_growth'].fillna(energy['gdp_growth'].median())

# %%
energy['gdp_per_capita']=energy['gdp_per_capita'].fillna(energy['gdp_per_capita'].median())

# %%
# def new_value(energy, column):
#     energy[column]=energy[column].dropna

#     energy[column]=energy[column].apply(lambda x: np.random.choice(energy[column]) if pd.isnull(x) else x )



# new_value(energy,'Renewable-electricity-generating-capacity-per-capita')

# new_value(energy,'Financial flows to developing countries (US $)')

# new_value(energy,'Value_co2_emissions_kt_by_country')

# new_value(energy,'Renewables (% equivalent primary energy)')

# new_value(energy,'gdp_growth')

# new_value(energy,'gdp_per_capita')

# %%
(energy.isnull().mean())*100
# Out:
# Entity                                                              0.0
# Year                                                                0.0
# Access to electricity (% of population)                             0.0
# Access to clean fuels for cooking                                   0.0
# Renewable-electricity-generating-capacity-per-capita                0.0
# Financial flows to developing countries (US $)                      0.0
# Renewable energy share in the total final energy consumption (%)    0.0
# Electricity from fossil fuels (TWh)                                 0.0
# Electricity from nuclear (TWh)                                      0.0
# Electricity from renewables (TWh)                                   0.0
# Low-carbon electricity (% electricity)                              0.0
# Primary energy consumption per capita (kWh/person)                  0.0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)         0.0
# ...

# %%
sns.distplot(x=energy["Year"])
plt.xlabel("Years")
plt.show()

# %%
energy.groupby("Year")["Access to electricity (% of population)"].mean().plot(kind="bar")
plt.xlabel('years')
plt.ylabel('Counts')
plt.show()

# %%
energy["Renewable-electricity-generating-capacity-per-capita"]
# Out:
# 0        9.22
# 1        8.86
# 2        8.47
# 3        8.09
# 4        7.75
#         ...
# 3644    62.88
# 3645    62.33
# 3646    82.53
# 3647    81.40
# 3648    80.61
# Name: Renewable-electricity-generating-capacity-per-capita, Length: 3649, dtype: float64

# %%
plt.figure(figsize=[15,5])
sns.scatterplot(data=energy,x='Year',y='Renewable-electricity-generating-capacity-per-capita')
plt.title('Energy Use Over Time to Individual ')
plt.ylabel('Renewable energy available per person')
plt.xlabel('years')
plt.show()

# %%
energy["Renewable energy share in the total final energy consumption (%)"]
# Out:
# 0       44.99
# 1       45.60
# 2       37.83
# 3       36.66
# 4       44.24
#         ...
# 3644    81.90
# 3645    82.46
# 3646    80.23
# 3647    81.50
# 3648    81.90
# Name: Renewable energy share in the total final energy consumption (%), Length: 3649, dtype: float64

# %%
plt.figure(figsize=[15,8])

plt.subplot(2,2,1)
sns.histplot(x=energy["Renewable energy share in the total final energy consumption (%)"])
plt.title('energy comes from renewables')

plt.subplot(2,2,2)
sns.distplot(x=energy["Electricity from fossil fuels (TWh)"])
plt.title('Power made from coal, gas, oil')

plt.subplot(2,2,3)
sns.histplot(x=energy["Electricity from nuclear (TWh)"])
plt.xlabel('Power made from nuclear plants',fontsize=12)

plt.subplot(2,2,4)
sns.distplot(x=energy["Electricity from renewables (TWh)"])
plt.xlabel('Power from wind, solar, water',fontsize=12)

plt.show()

# %%
energy.sample(5)
# Out:
#                       Entity  Year  Access to electricity (% of population)  \
# 3328     Trinidad and Tobago  2015                                100.00000
# 2482                  Norway  2010                                100.00000
# 3210             Switzerland  2002                                100.00000
# 2186              Montenegro  2008                                100.00000
# 452   Bosnia and Herzegovina  2011                                 99.70578
#
#       Access to clean fuels for cooking  \
# 3328                              100.0
# 2482                              100.0
# 3210                              100.0
# 2186                               64.2
# 452                                44.7
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 3328                                               2.61
# 2482                                              32.91
# 3210                                              32.91
# ...

# %%
energy['Low-carbon electricity (% electricity)']
# Out:
# 0       65.957440
# 1       84.745766
# 2       81.159424
# 3       67.021280
# 4       62.921350
#           ...
# 3644    48.680350
# 3645    58.503407
# 3646    59.412407
# 3647    55.582527
# 3648    55.204216
# Name: Low-carbon electricity (% electricity), Length: 3649, dtype: float64

# %%
sns.histplot(x=energy['Low-carbon electricity (% electricity)'])
plt.title('Clean electricity, like renewables or nuclear.')
plt.show()

# %%
energy['Primary energy consumption per capita (kWh/person)']
# Out:
# 0        302.59482
# 1        236.89185
# 2        210.86215
# 3        229.96822
# 4        204.23125
#            ...
# 3644    3227.68020
# 3645    3068.01150
# 3646    3441.98580
# 3647    3003.65530
# 3648    2680.13180
# Name: Primary energy consumption per capita (kWh/person), Length: 3649, dtype: float64

# %%
plt.figure(figsize=[15,6])
plt.subplot(1,2,1)
sns.histplot(x=energy['Primary energy consumption per capita (kWh/person)'])
plt.title('Energy used by one person')

plt.subplot(1,2,2)
sns.histplot(x=energy['Renewable-electricity-generating-capacity-per-capita'])
plt.title('Renewable energy available per person')

plt.show()

# %%
energy["gdp_growth"].value_counts()
# Out:
# gdp_growth
#  3.559855     317
#  3.800000       2
#  13.200000      2
#  3.300000       2
#  0.200000       2
#              ...
#  4.805453       1
#  5.473837       1
#  11.058723      1
#  5.794496       1
# -6.248748       1
# Name: count, Length: 3321, dtype: int64

# %%
plt.figure(figsize=[15,6])
sns.violinplot(x=energy["Year"],y=energy['gdp_growth'])
plt.title('GDP over Time')
plt.show()

# %%
energy.columns
# Out:
# Index(['Entity', 'Year', 'Access to electricity (% of population)',
#        'Access to clean fuels for cooking',
#        'Renewable-electricity-generating-capacity-per-capita',
#        'Financial flows to developing countries (US $)',
#        'Renewable energy share in the total final energy consumption (%)',
#        'Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)',
#        'Electricity from renewables (TWh)',
#        'Low-carbon electricity (% electricity)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#        'Value_co2_emissions_kt_by_country',
#        'Renewables (% equivalent primary energy)', 'gdp_growth',
#        'gdp_per_capita', 'Density\n(P/Km2)', 'Land Area(Km2)', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
plt.figure(figsize=[15,6])
sns.barplot(x=energy["Year"],y=energy['Value_co2_emissions_kt_by_country'])
plt.title('CO2 emissions increase  with pollution  increase ')
plt.show()

# %%
energy.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %%
energy_columns=[ 'Year', 'Access to electricity (% of population)',
       'Access to clean fuels for cooking',
       'Renewable-electricity-generating-capacity-per-capita',
       'Renewable energy share in the total final energy consumption (%)',
       'Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)',
       'Electricity from renewables (TWh)',
       'Low-carbon electricity (% electricity)',
       'Primary energy consumption per capita (kWh/person)',
       'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
       'Value_co2_emissions_kt_by_country',
       'Renewables (% equivalent primary energy)', 'gdp_growth',
        'Latitude']

er=pd.DataFrame(energy,columns=energy_columns)

# %%
er
# Out:
#       Year  Access to electricity (% of population)  \
# 0     2000                                 1.613591
# 1     2001                                 4.074574
# 2     2002                                 9.409158
# 3     2003                                14.738506
# 4     2004                                20.064968
# ...    ...                                      ...
# 3644  2016                                42.561730
# 3645  2017                                44.178635
# 3646  2018                                45.572647
# 3647  2019                                46.781475
# 3648  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# 3                                   9.5
# 4                                  10.9
# ...                                 ...
# 3644                               29.8
# ...

# %% [markdown]
# # Spliting

# %%
x=er.drop('Value_co2_emissions_kt_by_country',axis=1)

# %%
y=er['Value_co2_emissions_kt_by_country']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=30)

# %%
# scaling
from sklearn.preprocessing import RobustScaler

r=RobustScaler()

train_saclin=r.fit_transform(x_train)

test_saclin=r.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,StackingRegressor,VotingRegressor,BaggingRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score, KFold

# %%
k=KFold(n_splits=5)

# %%
list=[LinearRegression(),SVR(),DecisionTreeRegressor(),RandomForestRegressor(),
     KNeighborsRegressor()]

# %%
for i in list:
    print(i)
    print(cross_val_score(estimator=i,X=train_saclin,y=y_train,cv=k).mean())
# Out:
# LinearRegression()
# 0.8351224579313884
# SVR()
# -0.034425199210873905
# DecisionTreeRegressor()
# 0.8907185284274435
# RandomForestRegressor()
# 0.8956423117380229
# KNeighborsRegressor()
# 0.8839933894116243

# %% [markdown]
# # VotingRegressor

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.ensemble import StackingRegressor,VotingRegressor,BaggingRegressor,AdaBoostRegressor,GradientBoostingRegressor

# %%
lr=LinearRegression()
dt=DecisionTreeRegressor(max_depth=75)
kn=KNeighborsRegressor(n_neighbors=55)

# %%
voting_regressor = VotingRegressor(estimators=[('lr', lr), ('kn', kn), ('dt', dt)])

# %%
voting_regressor.fit(train_saclin,y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('kn', KNeighborsRegressor(n_neighbors=55)),
#                             ('dt', DecisionTreeRegressor(max_depth=75))])

# %%
voting_regressor.score(train_saclin,y_train)
# Out:
# 0.9203458182316533

# %%
voting_regressor.score(test_saclin,y_test)
# Out:
# 0.9126378392301193

# %%
y_pre=voting_regressor.predict(test_saclin)

# %%
from sklearn.metrics import r2_score,confusion_matrix,mean_absolute_error,mean_squared_error,root_mean_squared_error

# %%
r2_score(y_test,voting_regressor.predict(test_saclin))
# Out:
# 0.9126378392301193

# %%
mean_absolute_error(y_test,y_pre)
# Out:
# 32568.87079128873

# %%
mean_squared_error(y_test,y_pre)
# Out:
# 26693137044.035564

# %%
root_mean_squared_error(y_test,y_pre)
# Out:
# 163380.34472982227

# %% [markdown]
# # StackingRegressor

# %%
lr=LinearRegression()
dt=DecisionTreeRegressor()
kn=KNeighborsRegressor(n_neighbors=10)
rf=RandomForestRegressor(n_estimators=200,max_depth=65,min_samples_split=51)

# %%
sr=StackingRegressor(estimators=[('rf', rf), ('kn', kn), ('dt', dt)],final_estimator=LinearRegression())

# %%
sr.fit(train_saclin,y_train)
# Out:
# StackingRegressor(estimators=[('rf',
#                                RandomForestRegressor(max_depth=65,
#                                                      min_samples_split=51,
#                                                      n_estimators=200)),
#                               ('kn', KNeighborsRegressor(n_neighbors=10)),
#                               ('dt', DecisionTreeRegressor())],
#                   final_estimator=LinearRegression())

# %%
sr.score(train_saclin,y_train)
# Out:
# 0.9717132565939125

# %%
sr.score(test_saclin,y_test)
# Out:
# 0.9602245712563734

# %%
y_sr_pre=sr.predict(test_saclin)

# %%
mean_absolute_error(y_test,y_sr_pre)
# Out:
# 18732.411550470435

# %%
mean_squared_error(y_test,y_sr_pre)
# Out:
# 12153213257.116936

# %%
root_mean_squared_error(y_test,y_sr_pre)
# Out:
# 110241.61309195787

# %% [markdown]
# # BaggingRegressor

# %%
br=BaggingRegressor(estimator=DecisionTreeRegressor(),n_estimators=200,random_state=20)

# %%
br.fit(train_saclin,y_train)
# Out:
# BaggingRegressor(estimator=DecisionTreeRegressor(), n_estimators=200,
#                  random_state=20)

# %%
br.score(train_saclin,y_train)
# Out:
# 0.9893996844489819

# %%
br.score(test_saclin,y_test)
# Out:
# 0.9666227461595098

# %%
y_br_pre=sr.predict(test_saclin)

# %%
mean_absolute_error(y_test,y_br_pre)
# Out:
# 18732.411550470435

# %%
mean_squared_error(y_test,y_br_pre)
# Out:
# 12153213257.116936

# %%
root_mean_squared_error(y_test,y_br_pre)
# Out:
# 110241.61309195787

# %% [markdown]
# # AdaBoostRegressor

# %%
ab=AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=20),n_estimators=150,learning_rate=0.01)

# %%
ab.fit(train_saclin,y_train)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=20),
#                   learning_rate=0.01, n_estimators=150)

# %%
ab.score(train_saclin,y_train)
# Out:
# 0.9999999989665653

# %%
ab.score(test_saclin,y_test)
# Out:
# 0.9702714894977343

# %%
y_ab_pre=sr.predict(test_saclin)

# %%
mean_absolute_error(y_test,y_ab_pre)
# Out:
# 18732.411550470435

# %%
mean_squared_error(y_test,y_ab_pre)
# Out:
# 12153213257.116936

# %%
root_mean_squared_error(y_test,y_ab_pre)
# Out:
# 110241.61309195787

# %% [markdown]
# # GradientBoostingRegressor

# %%
gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# %%
gb_model.fit(train_saclin,y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
gb_model.score(train_saclin,y_train)
# Out:
# 0.999367962385762

# %%
gb_model.score(test_saclin,y_test)
# Out:
# 0.9668166900943755

# %%
y_gb_model_pre=sr.predict(test_saclin)

# %%
mean_squared_error(y_test,y_gb_model_pre)
# Out:
# 12153213257.116936

# %%
root_mean_squared_error(y_test,y_gb_model_pre)
# Out:
# 110241.61309195787

# %%
mean_absolute_error(y_test,y_gb_model_pre)
# Out:
# 18732.411550470435
